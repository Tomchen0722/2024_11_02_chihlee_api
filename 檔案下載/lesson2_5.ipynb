# %%
import requests
import ssl
url = 'https://opendata.cwa.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
#解決ssl驗証
#全部不驗証
ssl._create_default_https_context = ssl._create_unverified_context

response = requests.get(url,verify=False)
if response.ok:
    print("下載成功")
    json_str:str = response.text
else:
    print("下載失敗")
# Out:
# 下載成功
# /opt/conda/lib/python3.12/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.cwa.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
#解析json成python的資料結構
import json
jsonData = json.loads(json_str)
jsonData
# Out:
# {'success': 'true',
#  'result': {'resource_id': 'F-C0032-001',
#   'fields': [{'id': 'datasetDescription', 'type': 'String'},
#    {'id': 'locationName', 'type': 'String'},
#    {'id': 'parameterName', 'type': 'String'},
#    {'id': 'parameterValue', 'type': 'String'},
#    {'id': 'parameterUnit', 'type': 'String'},
#    {'id': 'startTime', 'type': 'Timestamp'},
#    {'id': 'endTime', 'type': 'Timestamp'}]},
#  'records': {'datasetDescription': '三十六小時天氣預報',
#   'location': [{'locationName': '嘉義縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '29', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '新北市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫雨', 'parameterValue': '9'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '嘉義市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '新竹縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '新竹市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺北市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫雨', 'parameterValue': '9'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺南市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '29', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '宜蘭縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '40', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '40', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '苗栗縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰時多雲短暫雨', 'parameterValue': '10'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '雲林縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '29', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '花蓮縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰時多雲短暫雨', 'parameterValue': '10'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺中市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '29', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '臺東縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '多雲短暫雨', 'parameterValue': '8'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '29', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '桃園市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰時多雲短暫雨', 'parameterValue': '10'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲時陰短暫雨', 'parameterValue': '9'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '南投縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '高雄市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '金門縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '27', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '屏東縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '31', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '28', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '基隆市',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '陰時多雲短暫雨', 'parameterValue': '10'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '60', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '50', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '澎湖縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '多雲時陰', 'parameterValue': '5'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '26', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '彰化縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '23', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適至悶熱'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '24', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '29', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '25', 'parameterUnit': 'C'}}]}]},
#    {'locationName': '連江縣',
#     'weatherElement': [{'elementName': 'Wx',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '多雲', 'parameterValue': '4'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}]},
#      {'elementName': 'PoP',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]},
#      {'elementName': 'MinT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]},
#      {'elementName': 'CI',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '舒適'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '舒適'}}]},
#      {'elementName': 'MaxT',
#       'time': [{'startTime': '2024-11-10 00:00:00',
#         'endTime': '2024-11-10 06:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 06:00:00',
#         'endTime': '2024-11-10 18:00:00',
#         'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#        {'startTime': '2024-11-10 18:00:00',
#         'endTime': '2024-11-11 06:00:00',
#         'parameter': {'parameterName': '21', 'parameterUnit': 'C'}}]}]}]}}

# %%
#由response實體方法json(),直接轉換為python的資料結構
jsonData1 = response.json()
jsonData1["success"]
jsonData1['records']['datasetDescription']
jsonRecords = jsonData1['records']['location']

# %%
weather_list:list[dict] = []
for item in jsonRecords:
    city_item:dict = {}
    city_item['城市'] = item['locationName']
    city_item['啟始時間'] = item['weatherElement'][0]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][0]['time'][0]['endTime']
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['最高溫度'] = float(item['weatherElement'][4]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list
# Out:
# [{'城市': '嘉義縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '新北市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '嘉義市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 22.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '新竹縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 23.0,
#   '感覺': '舒適'},
#  {'城市': '新竹市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 23.0,
#   '感覺': '舒適'},
#  {'城市': '臺北市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '臺南市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '宜蘭縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 23.0,
#   '感覺': '舒適'},
#  {'城市': '苗栗縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 22.0,
#   '最高溫度': 23.0,
#   '感覺': '舒適'},
#  {'城市': '雲林縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '花蓮縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '臺中市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '臺東縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 25.0,
#   '感覺': '舒適'},
#  {'城市': '桃園市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 23.0,
#   '感覺': '舒適'},
#  {'城市': '南投縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 22.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '高雄市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 26.0,
#   '感覺': '舒適'},
#  {'城市': '金門縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 23.0,
#   '感覺': '舒適'},
#  {'城市': '屏東縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 25.0,
#   '感覺': '舒適'},
#  {'城市': '基隆市',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 23.0,
#   '感覺': '舒適'},
#  {'城市': '澎湖縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 24.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '彰化縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 23.0,
#   '最高溫度': 24.0,
#   '感覺': '舒適'},
#  {'城市': '連江縣',
#   '啟始時間': '2024-11-10 00:00:00',
#   '結束時間': '2024-11-10 06:00:00',
#   '最低溫度': 21.0,
#   '最高溫度': 22.0,
#   '感覺': '舒適'}]

# %%
import pandas as pd
dataFrame = pd.DataFrame(weather_list)
dataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       2 dataFrame = pd.DataFrame(weather_list)
#       3 dataFrame
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#dataFrame可以使什麼?
#儲存為csv
#儲存為excel

#儲存為csv檔
dataFrame.to_csv('天氣預測1天.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       1 #dataFrame可以使什麼?
#       2 #儲存為csv
#       3 #儲存為excel
#       4
#       5 #儲存為csv檔
# ----> 6 dataFrame.to_csv('天氣預測1天.csv')
#
# NameError: name 'dataFrame' is not defined

# %%
#儲存為excel檔
dataFrame.to_excel('天氣預測1天.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #儲存為excel檔
# ----> 2 dataFrame.to_excel('天氣預測1天.xlsx')
#
# NameError: name 'dataFrame' is not defined

# %% [markdown]
# 檔案存取
# 在讀取或寫入文件之前，必須使用 Python 內建的 open( ) 函數開啟 文件。 這個函數將建立一個文件物件，這個文件物件會與真實的文件做連結，可讓您透過文件物件對文件進行存取動作。
# file object = open(file_name [, access_mode])
# UTF8 編碼資料還請加入另一個參數才可避免亂碼:encoding=‘utf-8'
# file object = open(file_name [, access_mode])
# file_name:file_name 參數是一個字串資料，代表包含要連結的文件名稱。
# access_mode:access_mode 確定文件必須打開的模式，包括讀取、寫 入、附加等等。稍後會列完整列表。這是可選參數，默認文件訪問模式為 讀取(r)。
# 存取模式	描述
# r	連結開啟僅供閱讀的文件， 這是預設模式。
# rb	以二進位方式連結開啟僅供閱讀的文件。
# r+	連結一個用於閱讀和寫作的文件。
# rb+	連結一個用於閱讀和寫作的二進位格式文件。
# w	連結文件後僅供寫入。 如果文件存在，則覆蓋該文件。 如果文件不存在，則建立一個新文件後進行寫入。
# wb	連結二進位格式的文件後僅供寫入。如果文件存在，則覆蓋該文件。 如果文件不存在，則建立一個新文件進行寫入。
# w+	連結文件後可以寫入和閱讀。如果文件存在，則覆蓋現有文件。 如果文件不存在，則建立一個新文件進行閱讀和寫入。
# wb+	連結二進位格式文件後可以寫入和閱讀。如果文件存在，則覆蓋現有文件。 如果文件不存在，則建立一個新文件進行閱讀和寫入。
# a	連結一個文件進行附加。 如果文件存在，將處於從後面加入的模式。 如果文件不存在，它將建立一個新文件進行寫入。
# ab	連結一個二進位格式文件進行附加。 如果文件存在，將處於從後面加入的模式。 如果文件不存在，它將建立一個新文件進行寫入。
# a+	連結一個文件進行附加與讀取。 如果文件存在，將處於從後面加入的模式。 如果文件不存在，它將建立一個新文件進行寫入與讀取。
# ab+	連結一個文件進行附加與二進位格式讀取。 如果文件存在，將處於從後面加入的 模式。 如果文件不存在，它將建立一個新文件進行寫入與讀取。

# %%
# 操作範例 1:請動手操作，並留意輸出結果
# 使用print()寫入
text = '''python與中文
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。'''

print(text ,file=open('data.txt','w',encoding='utf-8'))
#print(text ,file=open('data.txt','w'))

# %%
# 操作範例 1:請動手操作，並留意輸出結果
# 使用檔案實體方法write()寫入檔案
text = '''
python與中文
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
'''
file = open('sample1.txt','w',encoding='utf-8')
file.write(text)
file.close()

# %%
# 操作範例 2:請動手操作，並留意輸出結果
#建立50位學生,每位學生5個分數
# write()


import random

students = []
for _ in range(50):
    scores = [] #建立一個0元素的list
    for _ in range(5):
        scores += [random.randint(50,100)]
    students.append(scores)

file = open('students.txt','w',encoding='utf-8')
file.write(str(students))
file.close()

# %% [markdown]
# 檔案讀取方式
# read([size]) 方法
# read([size]) 方法從文件當前位置起讀取 size 個字元數量，若無參數，則代表讀取至文件結束為止。
# 中文、英數與換行都是一格。

# %%
# 操作範例:請動手操作，並留意輸出結果

file = open('data.txt', 'r', encoding='UTF-8') 
content = file.read()
print(content)
#file.close( )
print("-------------")
#file = open('data.txt', 'r', encoding='UTF-8') 
content2 = file.read(5)
print(content2)
file.close( )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # 操作範例:請動手操作，並留意輸出結果
# ----> 3 file = open('data.txt', 'r', encoding='UTF-8')
#       4 content = file.read()
#       5 print(content)
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %% [markdown]
# 檔案讀取方式
# readline 方法
# 這個方法每次讀出一行內容，所以讀取時占用緩衝區較小，比較適合大型文件讀取，讀取到沒有資料為止。
# 若不使用 readline 可用 with 敘述一行一行讀取資料，再使用 for 迴圈 逐一進行處理。
# len( ) 代表計算字串字數。
# readlines 方法
# 這方法將讀取整個文件所有行，保存在一個 list 內。
# 讀取文件後可搭配使用的方法
# strip() 去除字串首尾的空白。
# lstrip( ) 去除字串左邊的空白。
# rstrip( ) 去除字串右邊的空白。
# startswith(‘字元’): 第一個字元。

# %%
# 操作範例:請動手操作，並留意輸出結果

f=open('data1.txt', 'r', encoding='UTF-8') 
result = list( )
for line in f.readlines( ):
    line = line.strip( )
    if not len(line) or line.startswith('#'):
        continue 
    result.append(line)
f.close()
result.sort( )
print(result)
open('result-readlines.txt', 'w', encoding='UTF-8').write('%s' % '\n'.join(result))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 操作範例:請動手操作，並留意輸出結果
# ----> 3 f=open('data1.txt', 'r', encoding='UTF-8')
#       4 result = list( )
#       5 for line in f.readlines( ):
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data1.txt'

# %% [markdown]
# 寫入 CSV 檔案
# 必須加入 import csv
# 利用 writer( ) 可寫入資料，寫入時注意
# delimiter - 這是代表分隔符號
# quotechar - 這是代表包住字串的符號
# 使用 writerow( ) 方法進行特定的儲存格寫入

# %%
#csv寫入檔案
import csv
'''
編號, 國文, 英文, 數學, 自然, 社會
01, 87, 90, 56, 87, 89
02, 98, 56, 78, 90, 49
'''
with open('students.csv','w', newline='') as file:
    csvWriter = csv.writer(file)
    csvWriter.writerow(['編號', '國文', '英文', '數學', '自然', '社會'])
    csvWriter.writerow(['01', 87, 90, 56, 87, 89])
    csvWriter.writerow(['02', 98, 56, 78, 90, 49])
print("程式結束")
# Out:
# 程式結束

# %%
#csv寫人檔案
#建立50位學生,每位學生5個分數
import random
import csv

with open('students.csv','w', newline='', encoding='UTF-8') as file:
    csvWriter = csv.writer(file)
    csvWriter.writerow(['編號', '國文', '英文', '數學', '自然', '社會'])
    for i in range(50):
        scores = [str(i+1)] #建立一個1元素的list
        for _ in range(5):
            scores += [random.randint(50,100)]
        csvWriter.writerow(scores)
print("程式結束")
# Out:
# 程式結束

# %% [markdown]
# 讀取 CSV 檔案
# 逗點分隔（Comma-Separated Values，簡稱 csv）是一種簡單的文字檔格式，以逗號分隔不同欄位的資料，很多軟體在儲存與交換表格資料時都支援這樣的格式。
#
# CSV 格式是資料庫最常用的導入和導出格式。
# 資料均沒有類型，一切都是字串。
# 沒有字體或顏色與儲存格寬度高度的設置。
# Python 語法必須加入 import csv。
# 讀取儲存格資料:
# reader( ):依照每一列的編號 由0開始
# DictReader( )
# 以第一列的值為每一行的名稱，第一列不是資料
# 也可以重新命名，但第一列必須是資料

# %%
#我們使用 csv.reader 讀取出來的 rows 會是一個二維的 list
#裡面就是整張表格的資料，這裡我們把每一列的 list 直接輸出，執行後會像這樣：
import csv
with open('students.csv','r',encoding='UTF-8') as file:
    rows = csv.reader(file) #rows是一個generator
    print(rows.__class__)
    
    #for row in rows:
    #   print(row.__class__) #取出的是list物件
    studentsList = list(rows)
    print(studentsList)
# Out:
# <class '_csv.reader'>
# [['編號', '國文', '英文', '數學', '自然', '社會'], ['1', '61', '79', '99', '84', '57'], ['2', '95', '81', '63', '81', '65'], ['3', '60', '73', '72', '92', '57'], ['4', '57', '70', '60', '50', '89'], ['5', '69', '98', '54', '61', '86'], ['6', '100', '81', '76', '60', '73'], ['7', '58', '64', '51', '83', '57'], ['8', '83', '62', '70', '57', '80'], ['9', '79', '53', '51', '69', '100'], ['10', '71', '79', '52', '98', '82'], ['11', '50', '69', '53', '96', '64'], ['12', '83', '77', '65', '82', '84'], ['13', '78', '73', '89', '59', '100'], ['14', '67', '69', '94', '50', '91'], ['15', '75', '83', '62', '81', '70'], ['16', '64', '89', '68', '76', '60'], ['17', '52', '89', '69', '97', '58'], ['18', '89', '90', '80', '64', '52'], ['19', '76', '73', '50', '95', '67'], ['20', '90', '61', '66', '57', '59'], ['21', '75', '81', '50', '75', '89'], ['22', '82', '52', '100', '85', '73'], ['23', '70', '72', '64', '50', '96'], ['24', '62', '87', '65', '79', '76'], ['25', '68', '58', '83', '55', '83'], ['26', '76', '52', '89', '59', '69'], ['27', '97', '55', '80', '96', '66'], ['28', '90', '83', '87', '78', '98'], ['29', '80', '73', '99', '97', '54'], ['30', '92', '80', '57', '73', '99'], ['31', '59', '80', '54', '53', '67'], ['32', '94', '55', '50', '88', '62'], ['33', '70', '65', '69', '69', '93'], ['34', '78', '81', '61', '84', '71'], ['35', '100', '53', '87', '51', '83'], ['36', '59', '68', '98', '83', '100'], ['37', '64', '65', '72', '52', '59'], ['38', '54', '67', '68', '71', '58'], ['39', '76', '55', '77', '70', '100'], ['40', '98', '64', '64', '78', '81'], ['41', '62', '53', '66', '57', '84'], ['42', '63', '75', '94', '78', '71'], ['43', '50', '53', '93', '54', '75'], ['44', '96', '75', '80', '60', '57'], ['45', '86', '74', '82', '70', '68'], ['46', '84', '73', '59', '59', '56'], ['47', '99', '75', '55', '69', '77'], ['48', '87', '64', '97', '92', '83'], ['49', '67', '74', '68', '65', '56'], ['50', '100', '79', '86', '92', '70']]

# %%
#讀取CSV
import csv
with open('students.csv','r',encoding='UTF-8') as file:
    csvReader = csv.reader(file) #rows是一個generator
    print(csvReader.__class__)
    
    #for row in rows:
    #   print(csvReader.__class__) #取出的是list物件
    studentsList = list(csvReader)
    #print(studentsList)
    studentsList.pop(0)
    #print(studentsList)
    #list(map(int, ['1','2','3'])) #map的使用方法
    for index in range(len(studentsList)):
        student = studentsList[index]
        student = list(map(int, student))
        studentsList[index] = student
print(studentsList)    
studentIndex = int(input('請輸入學生編號(1-50):'))
for student in studentsList:
    if studentIndex == student[0]:
        print(student)
        break
print("程式結束")
# Out:
# <class '_csv.reader'>
# [[1, 61, 79, 99, 84, 57], [2, 95, 81, 63, 81, 65], [3, 60, 73, 72, 92, 57], [4, 57, 70, 60, 50, 89], [5, 69, 98, 54, 61, 86], [6, 100, 81, 76, 60, 73], [7, 58, 64, 51, 83, 57], [8, 83, 62, 70, 57, 80], [9, 79, 53, 51, 69, 100], [10, 71, 79, 52, 98, 82], [11, 50, 69, 53, 96, 64], [12, 83, 77, 65, 82, 84], [13, 78, 73, 89, 59, 100], [14, 67, 69, 94, 50, 91], [15, 75, 83, 62, 81, 70], [16, 64, 89, 68, 76, 60], [17, 52, 89, 69, 97, 58], [18, 89, 90, 80, 64, 52], [19, 76, 73, 50, 95, 67], [20, 90, 61, 66, 57, 59], [21, 75, 81, 50, 75, 89], [22, 82, 52, 100, 85, 73], [23, 70, 72, 64, 50, 96], [24, 62, 87, 65, 79, 76], [25, 68, 58, 83, 55, 83], [26, 76, 52, 89, 59, 69], [27, 97, 55, 80, 96, 66], [28, 90, 83, 87, 78, 98], [29, 80, 73, 99, 97, 54], [30, 92, 80, 57, 73, 99], [31, 59, 80, 54, 53, 67], [32, 94, 55, 50, 88, 62], [33, 70, 65, 69, 69, 93], [34, 78, 81, 61, 84, 71], [35, 100, 53, 87, 51, 83], [36, 59, 68, 98, 83, 100], [37, 64, 65, 72, 52, 59], [38, 54, 67, 68, 71, 58], [39, 76, 55, 77, 70, 100], [40, 98, 64, 64, 78, 81], [41, 62, 53, 66, 57, 84], [42, 63, 75, 94, 78, 71], [43, 50, 53, 93, 54, 75], [44, 96, 75, 80, 60, 57], [45, 86, 74, 82, 70, 68], [46, 84, 73, 59, 59, 56], [47, 99, 75, 55, 69, 77], [48, 87, 64, 97, 92, 83], [49, 67, 74, 68, 65, 56], [50, 100, 79, 86, 92, 70]]
# [1, 61, 79, 99, 84, 57]
# 程式結束

# %%
#請讀入資料集內的(各鄉鎮市區人口密度.csv)
#將資料轉為2維的list=>[[],[],[]]
#將資料轉為2維的list=>[{},{},{}]

import csv

poplist = []
f = open('各鄉鎮市區人口密度.csv','r',encoding='UTF-8')
csvReader = csv.reader(f)
for row in csvReader:
    if row[0] == '106':
        poplist.append(row)
f.close()
poplist
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 8
#       5 import csv
#       7 poplist = []
# ----> 8 f = open('各鄉鎮市區人口密度.csv','r',encoding='UTF-8')
#       9 csvReader = csv.reader(f)
#      10 for row in csvReader:
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '各鄉鎮市區人口密度.csv'

# %%
#請讀入資料集內的(各鄉鎮市區人口密度.csv)
#將資料轉為2維的list=>[{},{},{}]
import csv
poplist = list()
f = open('各鄉鎮市區人口密度.csv','r',encoding='UTF-8')
next(f)
reader = csv.DictReader(f)
data=[{'統計年':row['統計年'],'區域別':row['區域別'],'年底人口數':row['年底人口數'],'土地面積':row['土地面積'],'人口密度':row['人口密度']} for row in reader]
for item in data:
    if '新北市' in item['區域別']:
        poplist.append(item)
poplist
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 5
#       3 import csv
#       4 poplist = list()
# ----> 5 f = open('各鄉鎮市區人口密度.csv','r',encoding='UTF-8')
#       6 next(f)
#       7 reader = csv.DictReader(f)
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '各鄉鎮市區人口密度.csv'

# %% [markdown]
# Python 與 JSON
# Python 的資料型態與 JSON 的資料型態略有差異:
# Python 資料型態	JSON 資料型態
# dict	object
# list,tuple	array
# int,float	number
# True	true
# False	false
# None	null
# 從 Python 到 JSON
# 以 json.dumps( ) 函數從 Python dictionary轉出JSON字串。
# 以 json.dump( ) 函數從 Python dictionary轉出 JSON 檔案中。
# json資料於Python處理UTF8碼內容會產生亂碼，建議 dumps 時加入 以下的參數才可以正確處理UTF8碼內容:ensure_ascii=False
# Python 與 JSON 檔案:
# JSON 檔案的中文資料於某些編輯軟體內會變成亂碼，但 Python 可以存取。
# 檔案寫入可用一般文件方式寫入，也可以使用 JSON 的方法寫入。

# %%
# 操作範例 1:請動手操作，並留意輸出結果
# 將dictionary轉成json格式的字串

import json
pyDic = {'python': 'good', 'gjun': 100, 'python-class':True,'ICQ': None}
json2 = json.dumps(pyDic, ensure_ascii=False)
print(type(json2))
json3=json2.encode('utf8')
print(type(json3))
print(json2)
print(json3)

# %%
#將dictionary轉成json的字串
#使用json.dumps()
import json
codes = {'tw': 'Taiwan', 'jp': 'japan', 'hk': 'HongKong', 'us': '美國'}
print(codes.__class__)
jsonStr = json.dumps(codes,ensure_ascii=False)
jsonStr.__class__

#將json字串存成檔案使用open()方法
with open('codes.json','w',encoding='utf-8') as file:
    file.write(jsonStr)
print("json檔案存檔完成")
# Out:
# <class 'dict'>
# json檔案存檔完成

# %%
#將dictionary直接轉成json檔案
#使用json.dump()
import json
codes = {'tw': 'Taiwan', 'jp': 'japan', 'hk': 'HongKong', 'us': '美國'}
with open('codes1.json','w',encoding='utf-8') as file:
    json.dump(codes, file,ensure_ascii=False)
print("json檔案存檔完成")

# %%
# 操作範例 2:請動手操作，並留意輸出結果

import json
data = {}
data['people'] = []
data['people'].append({'name': 'Scott','website': 'stackabuse.com','from': 'Nebraska'})
data['people'].append({'name': 'Larry', 'website': 'google.com', 'from': 'Michigan'})

#使用dump寫入json檔案,必需使用python的dictionary物件
with open('data.json', 'w') as outfile:
    json.dump(data, outfile)

#使用write寫入使需使用的json字串格式
json2 = json.dumps(data)
file=open('score.json','w',encoding='utf-8')
file.write((json2));
file.close();

# %%
#建立50位學生,每位學生有5個分數
#list內放dictionary
import random
students = []
for i in range(1,51):
    stdDict = {'姓名':'stu' + str(i),
               '國文':random.randint(50,100),
               '英文':random.randint(50,100),
               '數學':random.randint(50,100),
               '自然':random.randint(50,100),
               '社會':random.randint(50,100),
              }
    students.append(stdDict)

#儲存為json的檔案格式
#使用json.dump()
#json可以儲存複雜的python的資料結構

import json
with open('students.json','w',encoding='utf-8') as file:
    json.dump(students, file, ensure_ascii=False)
print("json存檔成功")

# %% [markdown]
# json存檔成功
# 從 JSON 到 Python
# 以 json.loads( ) 函數從 JSON 字串中取出資料轉入 Python。
# 以 json.load( ) 函數從 JSON 檔案中取出資料轉入 Python。

# %%
#讀取students.json
#使用json的load()方法，載入students.json
import json
with open('students.json','r', encoding='utf-8') as file:
    students = json.load(file)
students

# %%
# 操作範例 1:請動手操作，並留意輸出結果
#使用loads將json格式的字串傳成python的Dict

import json
json1 = '{"python": "good", "gjun": 100, "python-class": true, "ICQ": null}'
json2 = json.loads(json1)
print(json2)
# Out:
# {'python': 'good', 'gjun': 100, 'python-class': True, 'ICQ': None}

# %%
# 操作範例 2:請動手操作，並留意輸出結果
#使用load()將json檔轉成Dictionary

import json

#data = json.load('score.json')  #會出錯

with open('score.json') as json_file:
    data = json.load(json_file)
    for p in data['people']:
        print('Name:' + p['name'])
        print('Website:' + p['website'])
        print('From:'+p['from'])
        print()

# %%
# 請處理(新北市公共自行車租賃系統.json)
# google搜尋online json viewer

import json
with open('新北市公共自行車租賃系統.json') as json_file:
    data = json.load(json_file)
    if data['success']:
        records = data['result']['records']
    else:
        print('讀取失敗')

for record in records:
    if '新店區' in record['sarea']:        
        print('區域',record['sarea'])
        print('站名',record['sna'])
        print('地址',record['ar'])
        print('緯經度座標[{},{}]'.format(record['lat'],record['lng']))
        print('全部數量',record['tot'])
        print('可借',record['sbi'])
        print('可還',record['bemp'])
        print('----------------------')
        print()

# %% [markdown]
# 下載json,解析json,轉存為csv檔
# 中央氣象局開放資料平臺之資料擷取API
# https://opendata.cwb.gov.tw/dist/opendata-swagger.html
# 一般天氣預報,今明36小時
# https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON

# %%
# 下載json,解析json,轉存為csv檔
import requests
import csv

def download_weather():
    url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'

    response = requests.get(url)
    if response.status_code == 200:
        print("下載成功")
        weather = response.json()
        return weather
    else:
        print("下載失敗")
        return False

def parse_json(w):
    location = w['cwbopendata']['dataset']['location']
    weather_list = []
    for item in location:
        city_item = {}
        city_item['城市'] = item['locationName']
        city_item['啟始時間'] = item['weatherElement'][1]['time'][0]['startTime']
        city_item['結束時間'] = item['weatherElement'][1]['time'][0]['endTime']
        city_item['最高溫度'] = float(item['weatherElement'][1]['time'][0]['parameter']['parameterName'])
        city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
        city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
        weather_list.append(city_item)
    
    return weather_list

def save_csv(data):
    with open('目前天氣.csv',mode='w',encoding='utf-8',newline='') as file:
        fieldnames = ['城市', '啟始時間','結束時間','最高溫度','最低溫度','感覺']
        writer = csv.DictWriter(file,fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(data)

def main():
    #下載json檔
    weather = download_weather()

    if weather != False:
        print("下載完畢")
    else:
        print("應用程式下載失敗")
        return
    
    csv_data = parse_json(weather)
    save_csv(csv_data)


if __name__ == "__main__":
    main()

# %% [markdown]
# 檔案進階操作
# 檔案存取與例外處理
# Python 的文件存取是透過 open( ) 方法建立文件物件方式進行存取， 如果文件不存在或讀取存限限制將會產生例外。
# 檔案存取例外為 IOError ，另外有兩個子類別:
# FileNotFoundError，代表 “找不到檔案”。
# PermissionError，代表 “沒有權限存取”。
# 操作範例:請動手操作，並留意輸出結果
# file_except1.py

# %%
try:
    f = open('data.txt', 'r', encoding="utf8") 
    print(f.read( ))
    
except FileNotFoundError: 
    print("找不到檔案")
except PermissionError: 
    print("你沒有權限存取")
except IOError: 
    print("其他檔案IO問題")
except: 
    print("其他例外")
    
f.close( )
# Out:
# python與中文
# 1. 我們來試試看中文儲存能力。
# 2. 許這個字會有編碼衝突風險。
# 3. 犇這個字必須是utf8編碼才有。

# %% [markdown]
# 關於檔案關閉動作
# 檔案開啟後須進行 close( ) 方法進行關閉動作。
# 若檔案沒關閉會造成:
# 開啟的文件物件會占用系統資源。
# Python 可以同時間開啟的文件數量有限制 (約 20 份文件)。
# 開啟文件物件的模式若為寫入 (w 或 a) 模式，一般都是暫存於緩衝區，系統閒置或文件關閉前才會進行寫入，若沒有進行 close( ) 動作可能造成文 件儲存不完整。

# %%
# 操作範例:請動手操作，並留意輸出結果
import os

class tryopenfile:
    def openfile(self, filePath):
        self.handle = open(filePath, 'w')
        self.handle.close()

if __name__ == '__main__':
    t = tryopenfile( )
    filePath = 'test.txt' 
    t.openfile(filePath) 
    os.remove(filePath) 
    print('success')

# %% [markdown]
# With 方式操作檔案
# 多個檔案存取時若前一個檔案產生 IO 例外，將會造成後面無法進行close( ) 動作。
# 以 with 方式操作檔案:
# 檔案存取仍有可能產生 IO 例外。
# 離開 with 區塊時檔案將會自動進行close( )動作，自動關閉檔案。

# %%
# 操作範例 1:請動手操作，並留意輸出結果
try:
    with open('data.txt', 'r', encoding="utf8") as f:
        print(f.read( ))
except FileNotFoundError:
    print("找不到檔案") 
except PermissionError:
    print("你沒有權限存取")
except IOError: 
    print("其他檔案IO問題")
except: 
    print("其他例外")
# Out:
# python與中文
# 1. 我們來試試看中文儲存能力。
# 2. 許這個字會有編碼衝突風險。
# 3. 犇這個字必須是utf8編碼才有。
